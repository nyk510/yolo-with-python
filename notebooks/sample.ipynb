# %%
import cv2
import matplotlib.pyplot as plt

from nyktk.detect import CV2YOLODetector
from nyktk.cv2_utils import draw_bbox, BoundingBox

# %matplotlib inline

# %%
yolo_detector = CV2YOLODetector()

# %%
img = cv2.imread('/home/sample/maeda.jpg')

# %% [markdown]
# ## 実行速度
#
# 何回かループを回して実行速度を計測する

# %%
# %%timeit

detections = yolo_detector.predict(img, only_person=True)
# Out:
# 602 ms ± 90.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
detections = yolo_detector.predict(img, only_person=True)
draw_img = img.copy()

# %%
for obj_id, prob, area in detections:
    bbox = BoundingBox(area)
    draw_img = draw_bbox(draw_img, bbox)

# %%
plt.imshow(draw_img[:, :, ::-1])
plt.axis('off')
plt.tight_layout()
plt.savefig('/home/sample/maeda_detect.png')
